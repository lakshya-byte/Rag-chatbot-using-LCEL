# %%
# %pip install torch sentence-transformers
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install "transformers<5.0.0" sentence-transformers torch --upgrade
# Out:
# ...
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    ------------ --------------------------- 3.7/12.0 MB 18.2 MB/s eta 0:00:01
#    ------------------- -------------------- 5.8/12.0 MB 14.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.9/12.0 MB 13.5 MB/s eta 0:00:01
#    ---------------------------------------  11.8/12.0 MB 13.2 MB/s eta 0:00:01
#    ---------------------------------------- 12.0/12.0 MB 11.7 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/566.4 kB ? eta -:--:--
#    ---------------------------------------- 566.4/566.4 kB 6.5 MB/s  0:00:00
# ...
#
#   Attempting uninstall: huggingface-hub
#
#     Found existing installation: huggingface_hub 1.7.1
#
#     Uninstalling huggingface_hub-1.7.1:
#
#    ---------------------------------------- 0/2 [huggingface-hub]
#       Successfully uninstalled huggingface_hub-1.7.1
#    ---------------------------------------- 0/2 [huggingface-hub]
# ...
